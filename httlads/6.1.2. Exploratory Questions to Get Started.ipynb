# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/ivan.sobolev/Downloads/world_countries.csv")

# %%
df.head()
# Out:
#           Country Code                Region  Population     Area  \
# 0     Afghanistan  AFG  ASIA (EX. NEAR EAST)    31056997   647500
# 1         Albania  ALB        EASTERN EUROPE     3581655    28748
# 2         Algeria  DZA       NORTHERN AFRICA    32930091  2381740
# 3  American Samoa  ASM               OCEANIA       57794      199
# 4         Andorra  AND        WESTERN EUROPE       71201      468
#
#    Pop. Density  Coastline  Net migration  Infant mortality      GDP  ...  \
# 0          48.0       0.00          23.06            163.07    700.0  ...
# 1         124.6       1.26          -4.93             21.52   4500.0  ...
# 2          13.8       0.04          -0.39             31.00   6000.0  ...
# 3         290.4      58.29         -20.71              9.27   8000.0  ...
# 4         152.1       0.00           6.60              4.05  19000.0  ...
#
#    Phones  Arable  Crops  Other  Climate  Birthrate  Deathrate  Agriculture  \
# ...

# %%
df.describe()
# Out:
#          Population          Area  Pop. Density   Coastline  Net migration  \
# count  2.240000e+02  2.240000e+02     224.00000  224.000000     221.000000
# mean   2.910685e+07  6.062069e+05     363.50000   21.229911       0.019774
# std    1.186386e+08  1.800941e+06    1653.83232   72.745873       4.917240
# min    7.026000e+03  2.000000e+00       0.00000    0.000000     -20.990000
# 25%    4.383705e+05  5.609500e+03      28.80000    0.100000      -0.980000
# 50%    5.128409e+06  8.968050e+04      77.40000    0.725000       0.000000
# 75%    1.789000e+07  4.467625e+05     182.52500    9.960000       0.970000
# max    1.313974e+09  1.707520e+07   16271.50000  870.660000      23.060000
#
#        Infant mortality           GDP    Literacy       Phones      Arable  \
# count        221.000000    223.000000  208.000000   220.000000  222.000000
# mean          35.751041   9762.780269   82.771635   235.849545   13.731982
# ...

# %%
# Q-1: What are the minimum and maximum values of the data in each column?
mms = pd.DataFrame({'min': df.min(), 'max': df.max()})
mms
# Out:
#                                    min             max
# Country                    Afghanistan        Zimbabwe
# Code                               ABW             ZWE
# Region            ASIA (EX. NEAR EAST)  WESTERN EUROPE
# Population                        7026      1313973713
# Area                                 2        17075200
# Pop. Density                         0         16271.5
# Coastline                            0          870.66
# Net migration                   -20.99           23.06
# Infant mortality                  2.29          191.19
# GDP                                500           55100
# Literacy                          17.6             100
# Phones                             0.2          1035.6
# Arable                               0           62.11
# Crops                                0           50.68
# Other                            33.33             100
# Climate                              1               4
# ...

# %%
# Q-2: How does the birth rate compare across countries? What is the distribution of the birth rates?
df['Birthrate'].hist()

# %%
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
alt.Chart(df).mark_point().encode(
    x='Region',
    y='GDP',
    size='Birthrate'
)

# %%
df['Birthrate'].hist()

# %%
# Q-3: Is there are connection between the area of a country and its population?
alt.Chart(df).mark_point().encode(
    x='Area',
    y='Population',
)

# %%
alt.Chart(df).mark_point().encode(
    alt.X('Area', scale=alt.Scale(type='log')),
    alt.Y('Population', scale=alt.Scale(type='log')),
    to
)

# %%
# Q-4: How can we find all of the details on a specific country?
df[df['Country'] == 'Albania'].transpose()
# Out:
#                                1
# Country                  Albania
# Code                         ALB
# Region            EASTERN EUROPE
# Population               3581655
# Area                       28748
# Pop. Density               124.6
# Coastline                   1.26
# Net migration              -4.93
# Infant mortality           21.52
# GDP                         4500
# Literacy                    86.5
# Phones                      71.2
# Arable                     21.09
# Crops                       4.42
# Other                      74.49
# Climate                        3
# Birthrate                  15.11
# Deathrate                   5.22
# Agriculture                0.232
# Industry                   0.188
# Service                    0.579
